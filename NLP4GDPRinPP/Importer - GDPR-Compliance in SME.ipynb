# %% [markdown]
# # Privacy Policy Scraper
# Python script to scrape privacy policies from Google search results.
# The script makes use of:
#  - googlesearch library (https://python-googlesearch.readthedocs.io/en/latest/genindex.html)
#  - newspaper library (https://newspaper.readthedocs.io/en/latest/user_guide/quickstart.html#performing-nlp-on-an-article)
#  - nltk (http://www.nltk.org/api/nltk.tokenize.html?highlight=punkt)
#
#  Inspired by:
#  https://pythondata.com/quick-tip-consuming-google-search-results-to-use-for-web-scraping/

# %%
# Import libs
import os
from googlesearch import search
from newspaper import Article
from six.moves.urllib.parse import urlparse
import nltk
import pandas as pd
import spacy
from googlesearch import search
from langdetect import detect
import re

# %% [markdown]
# ## Import SMEs and LE

# %% [markdown]
# The following datasets are collected through Orbis Europe:
# - dataset 1 (SMEs): SME_50000_Export 17_05_2021_12_54.xlsx
# - dataset 1 (LEs): LE_50000_Export 17_05_2021_12_54.xlsx

# %%
# load companies' data
data_sme = pd.read_excel('data/SME_50000_Export 17_05_2021_12_54.xlsx', index_col=0, header=0, sheet_name='Results')
data_le = pd.read_excel('data/LE_50000_Export 17_05_2021_12_54.xlsx', index_col=0, header=0, sheet_name='Results')

# %%
data_sme.head()
# Out:
#     Company name Latin alphabet Inactive Quoted Branch OwnData Woco  \
# 1.0         VIVACE LOGISTICA SA       No     No     No      No   No
# NaN                         NaN      NaN    NaN    NaN     NaN  NaN
# 2.0                       MENSA       No     No     No      No   No
# NaN                         NaN      NaN    NaN    NaN     NaN  NaN
# 3.0           MINITEC ESPANA SL       No     No     No      No   No
#
#     Country ISO code  NACE Rev. 2, core code (4 digits) Consolidation code  \
# 1.0               ES                             5210.0                 U1
# NaN              NaN                                NaN                NaN
# 2.0               FR                             4711.0                 U1
# NaN              NaN                                NaN                NaN
# 3.0               ES                             2849.0                 U1
#
#      Last avail. year  ...  Number of employees\nLast avail. yr  \
# 1.0            2018.0  ...                                   84
# NaN               NaN  ...                                  NaN
# 2.0            2019.0  ...                                 n.a.
# NaN               NaN  ...                                  NaN
# 3.0            2019.0  ...                                   39
#
#     Additional address(es) - Country  \
# 1.0                              NaN
# NaN                              NaN
# 2.0                              NaN
# NaN                              NaN
# 3.0                              NaN
#
#     Additional address(es) - Country ISO code  \
# 1.0                                       NaN
# NaN                                       NaN
# 2.0                                       NaN
# NaN                                       NaN
# 3.0                                       NaN
#
#     Additional address(es) - Standardized city  \
# 1.0                                        NaN
# NaN                                        NaN
# 2.0                                        NaN
# NaN                                        NaN
# 3.0                                        NaN
#
#     NAICS 2017, core code (4 digits)   NAICS 2017, core code - description  \
# 1.0                           4931.0               Warehousing and Storage
# NaN                              NaN                                   NaN
# 2.0                           4451.0                        Grocery Stores
# NaN                              NaN                                   NaN
# 3.0                           3335.0  Metalworking Machinery Manufacturing
#
#     NAICS 2017, primary code(s)  \
# 1.0                    493110.0
# NaN                    493190.0
# 2.0                    445110.0
# NaN                    445120.0
# 3.0                    333517.0
#
#              NAICS 2017, primary code(s) - description  \
# 1.0                    General Warehousing and Storage
# NaN                      Other Warehousing and Storage
# 2.0  Supermarkets and Other Grocery (except Conveni...
# NaN                                 Convenience Stores
# 3.0                         Machine Tool Manufacturing
#
#            NAICS 2017, secondary code(s) - description  \
# 1.0    All Other Support Activities for Transportation
# NaN                                                NaN
# 2.0                                                NaN
# NaN                                                NaN
# 3.0  Other Commercial and Service Industry Machiner...
#
#          NAICS 2017, secondary code(s) - description.1
# 1.0    All Other Support Activities for Transportation
# NaN                                                NaN
# 2.0                                                NaN
# NaN                                                NaN
# 3.0  Other Commercial and Service Industry Machiner...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Extract list of company names

# %%
# Get list of company names
# SME_list = data_sme['Company name Latin alphabet'].to_list()
SME_list = [name for name in data_sme['Company name Latin alphabet'].to_list() if str(name) != 'nan']
LE_list = [name for name in data_le['Company name Latin alphabet'].to_list() if str(name) != 'nan']

# %%
SME_list[:5]
# Out:
# ['VIVACE LOGISTICA SA',
#  'MENSA',
#  'MINITEC ESPANA SL',
#  'SNEXI',
#  'PHARMACIE DE LA GRANGE LUX FORTINA']

# %% [markdown]
# ## Select random policies for validation of the classification model

# %%
import random
i=0
idx_list = []
for i in range(50):
    idx_list.append((random.randint(0, len(SME_list)-1)))
print(idx_list)
# Out:
# [10926, 47193, 43768, 22477, 25883, 8274, 20550, 32552, 43751, 32033, 46787, 4063, 12873, 94, 1071, 13104, 36085, 11271, 40874, 26559, 47419, 590, 1325, 43843, 36509, 32343, 537, 31989, 45706, 31615, 9482, 13785, 48261, 29938, 43293, 892, 48970, 16905, 46133, 11607, 625, 45932, 2780, 2836, 26139, 3564, 21041, 36451, 15752, 5668]

# %% [markdown]
# #### Randomly selected privacy policies (we will use the first 10) that will be manually labeled to validate the classification model for both SME and LE
# [15991, 16719, 34111, 5317, 27629, 47251, 47641, 27152, 17003, 15962, 43942, 4178, 15640, 32350, 1895, 15762, 32443, 3645, 2255, 2876, 47697, 11464, 12510, 21791, 14217, 253, 42911, 22824, 12261, 45549]

# %% [markdown]
# ## SMEs and LEs: scrape policies for the test set

# %%
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# Scrape policies from google. Search for the words "privacy" or "policy" or "notice" in the url of the potential policy.
# We only pick the 1st result, unless the first result doesn't have the key terms in the URL, or if it is in a different language
# than English. We make 3 attempts before we go on to the next company in the list of SMEs or LEs. In short, we use the following reqs:
# - English language;
# - longer than 19 sentences (Avg SME: 101, Avg LE: 70);
# - 3 attempts to find a privacy policy based on company name.

# %%
def scrape_policies_google(query):
    in_title = 0
    attempts = 0
    policies = []
    sentences = []
    for url in search(query, lang='en'):
        attempts = attempts + 1
        
        if re.findall('privacy', url) or re.findall('policy', url) or re.findall('notice', url): 
            try:
                article = Article(url)
                article.download() #Downloads the link’s HTML content
                article.parse() #Parse the article
#                 print(article.title)
                doc = nlp(article.text)
                if detect(article.text) == 'en' and len(list(doc.sents)) > 19:
                    print(url)
                    sentences = list(doc.sents)
                    in_title = 1
#                     counter = counter + 1 
#                     print("Number of scraped policies: ", counter)
            except:
                pass
        if in_title == 1 or attempts == 3: 
            in_title = 0
            attempts = 0
            break        
    return sentences

# %% [markdown]
# Create list comprising of the randomly selected companies

# %%
selected_sme = [SME_list[i] for i in idx_list]
selected_le = [LE_list[i] for i in idx_list]
selected_sme
# Out:
# ['G2L NIORT',
#  'TEATE ECOLOGIA - S.P.A.',
#  'POLSOFT ENGINEERING SP. Z O.O.',
#  'THRACE ANGUS FARM EOOD',
#  'ALFAFIBER SP. Z O.O.',
#  'CASARRUBIO IMPORT EXPORT S.L.',
#  "SPORTPIU' SALUTE E BENESSERE SPORTIVA DILETTANTISTICA S.R.L.",
#  'SCHWUNG HOME SP. Z O.O.',
#  'D B PROGETTI S.R.L.',
#  'HANSPETER BIEHLER GMBH',
#  'ASCO ASSISTANCE & CONSEIL',
#  'CASINO MANHATTAN SRL',
#  'FRERES EN BIENS',
#  'MOON C',
#  'MILANO FOOD SERVICE S.R.L.',
#  'MAFRECAL, LDA',
#  'OEC OPTO DEVICES GMBH',
#  "COMPAGNIA RICICLAGGIO INERTI SOCIETA' A RESPONSABILITA' LIMITATA (ENUNCIABILE ANCHE COME CO.R.I. S.R.L. )",
#  'SMART INDUSTRIES LESNA INDUSTRIJA D.O.O.',
#  'AXPE CONSULTING SL',
#  'PERLAPELLE S.R.L.',
#  'SATKO OOD',
#  'ARMANDO GOMES LINDO & FILHOS, LDA',
#  'ADVITIS',
#  'I.DE.I CONCEPTS AB',
#  'KARO 06 EOOD',
#  'EXICOM, S.R.O.',
#  'ELFA SRL',
#  'ELEKTROTECHNIK BUERGLER & MOOSLECHNER GMBH',
#  'SCANTEST SIA',
#  'GLORIA CERVECEROS S.L.',
#  "FRIENDZ SOCIETA' A RESPONSABILITA' LIMITATA",
#  'SPOLDZIELNIA PRACY SPECJALISTOW RENTGENOLOGOW IM. PROF. WITOLDA ZAWADOWSKIEGO',
#  'C.A.D. EURO POOL MARCHE - S.R.L.',
#  '2HB ANS',
#  "DALLA LONGA SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICATA",
#  'NAVIGARE SCHIFFAHRT- UND SPEDITIONS-GMBH',
#  "CENTRE D'IMAGERIE MEDICALE PAU-VERDUN",
#  'INTERMEDIA CALL 2005 SRL',
#  'ATRANSBUT SL',
#  'TRIANGLE DAUPHINE',
#  'ELIO GROUP, S.R.O.',
#  'CELSO',
#  'NIKOLA HORACKOVA',
#  'KAESER KOMPRESSOREN SE',
#  'TECHNI CABLE',
#  'TEGRA LATVIA SIA',
#  'MEGABLEU',
#  'EMBA DUO BETETI TARSASAG',
#  'GUITARD CHRISTIAN']

# %% [markdown]
# #### SMEs

# %%
pps_sme = []
counter = []

for company in selected_sme:
    query = company + " privacy policy"
    print(" - - - " + company + " - - - ")
    out = scrape_policies_google(query)
    
    if(len(out) != 0):
        pps_sme.extend(out)
        counter.append(out)
        print("Number of scraped policies: ", len(counter))
        print("")
    if(len(counter) == 20):
        break
# Out:
#  - - - G2L NIORT - - -
# 181
# https://go-2-learn.com/g2l-privacy-policy/
# Number of scraped policies:  1
#
#  - - - TEATE ECOLOGIA - S.P.A. - - -
#  - - - POLSOFT ENGINEERING SP. Z O.O. - - -
#  - - - THRACE ANGUS FARM EOOD - - -
#  - - - ALFAFIBER SP. Z O.O. - - -
# 61
# https://user.com/en/privacy-policy/
# Number of scraped policies:  2
#
#  - - - CASARRUBIO IMPORT EXPORT S.L. - - -
#  - - - SPORTPIU' SALUTE E BENESSERE SPORTIVA DILETTANTISTICA S.R.L. - - -
# 100
#  - - - SCHWUNG HOME SP. Z O.O. - - -
# 3
#  - - - D B PROGETTI S.R.L. - - -
#  - - - HANSPETER BIEHLER GMBH - - -
# 9
#  - - - ASCO ASSISTANCE & CONSEIL - - -
# 371
# https://www.asco.org/about-asco/legal/privacy-policy
# Number of scraped policies:  3
#
#  - - - CASINO MANHATTAN SRL - - -
# 156
# https://www.cashmio.com/privacy-policy
# Number of scraped policies:  4
#
#  - - - FRERES EN BIENS - - -
# 129
# https://www.cnp.be/privacy-policy/
# Number of scraped policies:  5
#
#  - - - MOON C - - -
# 467
# https://mooncamp.com/privacy-policy/
# Number of scraped policies:  6
#
#  - - - MILANO FOOD SERVICE S.R.L. - - -
# 580
# https://www.pizzaandfoodmilano.it/en/privacy
# Number of scraped policies:  7
#
#  - - - MAFRECAL, LDA - - -
#  - - - OEC OPTO DEVICES GMBH - - -
# 81
# https://www.optodevices.de/en/privacy/
# Number of scraped policies:  8
#
#  - - - COMPAGNIA RICICLAGGIO INERTI SOCIETA' A RESPONSABILITA' LIMITATA (ENUNCIABILE ANCHE COME CO.R.I. S.R.L. ) - - -
#  - - - SMART INDUSTRIES LESNA INDUSTRIJA D.O.O. - - -
#  - - - AXPE CONSULTING SL - - -
#  - - - PERLAPELLE S.R.L. - - -
# 143
# 43
# https://mycli.com/cookieprivacy/
# Number of scraped policies:  9
#
#  - - - SATKO OOD - - -
#  - - - ARMANDO GOMES LINDO & FILHOS, LDA - - -
#  - - - ADVITIS - - -
# 81
# https://advmedia.io/privacy-policy/
# Number of scraped policies:  10
#
#  - - - I.DE.I CONCEPTS AB - - -
#  - - - KARO 06 EOOD - - -
#  - - - EXICOM, S.R.O. - - -
# 59
# https://exicom.se/en/about-us/privacy-policy/
# Number of scraped policies:  11
#
#  - - - ELFA SRL - - -
# 3
#  - - - ELEKTROTECHNIK BUERGLER & MOOSLECHNER GMBH - - -
#  - - - SCANTEST SIA - - -
# 0
#  - - - GLORIA CERVECEROS S.L. - - -
# 9
# 76
# https://www.gloria-books.com/privacy-policy
# Number of scraped policies:  12
#
#  - - - FRIENDZ SOCIETA' A RESPONSABILITA' LIMITATA - - -
# 0
#  - - - SPOLDZIELNIA PRACY SPECJALISTOW RENTGENOLOGOW IM. PROF. WITOLDA ZAWADOWSKIEGO - - -
#  - - - C.A.D. EURO POOL MARCHE - S.R.L. - - -
#  - - - 2HB ANS - - -
# 89
# 53
# https://www.dragonflycrowd.co.uk/privacy-policy/
# Number of scraped policies:  13
#
#  - - - DALLA LONGA SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICATA - - -
# 238
# 0
#  - - - NAVIGARE SCHIFFAHRT- UND SPEDITIONS-GMBH - - -
# 7
#  - - - CENTRE D'IMAGERIE MEDICALE PAU-VERDUN - - -
#  - - - INTERMEDIA CALL 2005 SRL - - -
#  - - - ATRANSBUT SL - - -
# 32
# https://www.base.be/en/legal-information/privacy-policy.html
# Number of scraped policies:  14
#
#  - - - TRIANGLE DAUPHINE - - -
# 24
# http://triangle.org.uk/page/privacy-policy
# Number of scraped policies:  15
#
#  - - - ELIO GROUP, S.R.O. - - -
# 6
#  - - - CELSO - - -
# 49
# https://celsodelemos.com/privacy-policy/en/
# Number of scraped policies:  16
#
#  - - - NIKOLA HORACKOVA - - -
#  - - - KAESER KOMPRESSOREN SE - - -
# 46
# https://www.kaeser.com/int-en/privacy.aspx
# Number of scraped policies:  17
#
#  - - - TECHNI CABLE - - -
# 84
# https://techni.no/about/privacy-policy
# Number of scraped policies:  18
#
#  - - - TEGRA LATVIA SIA - - -
#  - - - MEGABLEU - - -
#  - - - EMBA DUO BETETI TARSASAG - - -
#  - - - GUITARD CHRISTIAN - - -
# 33
# https://www.ebaa.org/privacy-policy/
# Number of scraped policies:  19

# %% [markdown]
# #### LEs

# %%
pps_le = []
counter = []

for company in selected_le:
    query = company + " privacy policy"
    print(" - - - " + company + " - - - ")
    out = scrape_policies_google(query)
    
    if(len(out) != 0):
        pps_le.extend(out)
        counter.append(out)
        print("Number of scraped policies: ", len(counter))
        print("")
    if(len(counter) == 20):
        break
# Out:
#  - - - NA FASTIGHETER AB - - -
#  - - - SCAUTO - - -
# 7
# 38
# https://www.scautorepair.com/privacy-policy.html
# Number of scraped policies:  1
#
#  - - - ESSOR AGRO - - -
#  - - - HERMANOS GELIDA SA - - -
#  - - - AMASTEN NYNASHAMN AB - - -
#  - - - PROMOCIONES ORCERA SL - - -
# 131
# https://www.helixperiences.com/en/privacy-policy
# Number of scraped policies:  2
#
#  - - - V FRANCE - - -
# 91
# https://www.politico.eu/article/europe-privacy-rules-survived-years-of-negotiations-lobbying/
# Number of scraped policies:  3
#
#  - - - CORPUS SIREO PROJEKTENTWICKLUNG WOHNEN GMBH - - -
#  - - - BILKOMPANIET GAVLEBORG AB - - -
#  - - - THELLIER CAMPING CAR - - -
#  - - - UNIVERSITAETSKLINIKUM SCHLESWIG-HOLSTEIN CAMPUS KIEL - - -
#  - - - TELFORT ZAKELIJK B.V. - - -
# 48
#  - - - IMECO SA - - -
#  - - - TRMC - - -
# 52
# https://www.trmchealth.org/privacy-policy/
# Number of scraped policies:  4
#
#  - - - SAGEMCOM HOLDING - - -
# 69
# https://www.sagemcom.com/legal-notice/
# Number of scraped policies:  5
#
#  - - - DELFINO - - -
# 65
# http://www.delfinocorporateevents.com/privacy-policy.html
# Number of scraped policies:  6
#
#  - - - AZZ WSI SP. Z O.O. - - -
#  - - - FIRST ROTTERDAM GEBOUW A B.V. - - -
#  - - - PETROL GAMMA S.R.L. - - -
# 0
#  - - - BECKER SAS - - -
# 167
# https://www.becker.com/privacy-policy
# Number of scraped policies:  7
#
#  - - - MEMINI S.R.L. - - -
# 0
# 13
#  - - - ENECO SMART ENERGY B.V. - - -
# 0
# 0
# 5
#  - - - FASTIGHETS AB ANGSHOLMSGRAND 5 - - -
# 149
# https://home.kpmg/be/en/home/misc/privacy.html
# Number of scraped policies:  8
#
#  - - - BOUYOUD - - -
#  - - - ABANCA RENTA VARIABLE MIXTA FI - - -
#  - - - INOXIDABLES DE EUSKADI SA - - -
#  - - - SAGAS AUTOMOBILE - - -
# 25
# https://www.saga.co.uk/privacy-policy
# Number of scraped policies:  9
#
#  - - - WP XII FINANCIAL HOLDINGS COOPERATIEF U.A. - - -
#  - - - KURIKAN VESIHUOLTO OY - - -
#  - - - ARTI GRAFICHE BOCCIA - S.P.A. - - - -
#  - - - REIWAG FACILITY SERVICES D.O.O. - - -
# 99
# http://www.reiwag.hr/en/privacy-policy
# Number of scraped policies:  10
#
#  - - - CASEIFICIO GENNARI SERGIO & FIGLI SOCIETA' A RESPONSABILITA' LIMI TATA - - -
#  - - - PCM.DE GMBH - - -
# 362
# 0
#  - - - ELASTICSEARCH FINANCE B.V. - - -
#  - - - CEMBRE ESPANA SL - - -
#  - - - STICHTING SEVERINUS - - -
# 25
#  - - - EQUITIX PLENIUM SOLAR 4 S.R.L. - - -
#  - - - IMET-AKE, S.R.O. - - -
# 63
# https://imet-ake.sk/gdpr-privacy-policy/
# Number of scraped policies:  11
#
#  - - - BEHR THERMOT-TRONIK GMBH ST. GEORGEN - - -
#  - - - AL-ALBA ESE GRANADA ALMERIA SL - - -
#  - - - BV ZAHLUNGSSYSTEME GMBH - - -
#  - - - OTI GREENTECH AG - - -
# 42
# https://oti.ag/en/privacy-policy/
# Number of scraped policies:  12
#
#  - - - PPG INDUSTRIES NETHERLANDS B.V. - - -
# 123
# http://corporate.ppg.com/legal-notices-and-privacy-policy.aspx
# Number of scraped policies:  13
#
#  - - - BAVARIAN NORDIC A/S - - -
# 135
# https://www.bavarian-nordic.com/privacy.aspx
# Number of scraped policies:  14
#
#  - - - HAMBURGER FRIEDHOEFE  -AOER- - - -
# 22
# https://www.friedhof-hamburg.de/en/privacy/
# Number of scraped policies:  15
#
#  - - - FEJ - - -
# 186
# https://fejgear.com/pages/privacy-policy
# Number of scraped policies:  16
#
#  - - - FINANCIERE DES MAUGES - - -
#  - - - KONSTRUKTA D.O.O. - - -
# 118
#  - - - AREA COOLING SOLUTIONS SA. - - -
# 111
# https://areacooling.com/privacy-policy/
# Number of scraped policies:  17
#
#  - - - AX-IT SYSTEME GMBH"  ZWEIGNIEDERLASSUNG OESTERREICH - - -
# 3

# %% [markdown]
# ### Clean policies
# Clean the privacy policy texts:
# - lowercase
# - remove newlines

# %%
pps_sme = [(str(sen).lower()).replace(";","") for sen in pps_sme if len(sen) > 3]
pps_le = [(str(sen).lower()).replace(";","") for sen in pps_le if len(sen) > 3]

# %%
print(len(pps_sme))
print(len(pps_sme)/20)
print(len(pps_le))
print(len(pps_le)/20)
# Out:
# 2009
# 100.45
# 1397
# 69.85

# %% [markdown]
# Test set statistics:
# - Avg number of sentences in policy SMEs: 101
# - Avg number of sentences in policy SMEs: 70

# %% [markdown]
# ### Save policies
# Save the privacy policy texts as csv

# %%
# pps_sme = [(str(sen).lower()) for sen in pps_sme if len(sen) > 3]

zer_list = [0] * len(pps_sme)

print(len(zer_list))
# d = {'Text': pps, 'DPO': zer_list, 'Purpose': zer_list, 'Acquired data': zer_list, 'Data sharing': zer_list, 'Rights': zer_list}

df_sme = pd.DataFrame(list(zip(pps_sme, zer_list,zer_list,zer_list,zer_list,zer_list)),
                                 columns =['Text', 'DPO', 'Purpose', 'Acquired data', 'Data sharing', 'Rights'])

# extra cleaning
df_sme = df_sme.replace('\n',' ', regex=True)
# Out:
# 2009

# %%
zer_list = [0] * len(pps_le)
# d = {'Text': pps, 'DPO': zer_list, 'Purpose': zer_list, 'Acquired data': zer_list, 'Data sharing': zer_list, 'Rights': zer_list}

df_le = pd.DataFrame(list(zip(pps_le, zer_list,zer_list,zer_list,zer_list,zer_list)),
                                 columns =['Text', 'DPO', 'Purpose', 'Acquired data', 'Data sharing', 'Rights'])

# extra cleaning
df_le = df_le.replace('\n',' ', regex=True)

# %%
df_le
# Out:
#                                                    Text  DPO  Purpose  \
# 0     this privacy policy sets out how s.c. auto rep...    0        0
# 1     s.c. auto repairs is committed to ensuring tha...    0        0
# 2     should we ask you to provide certain informati...    0        0
# 3     s.c. auto repairs may change this policy from ...    0        0
# 4     you should check this page from time to time t...    0        0
# ...                                                 ...  ...      ...
# 1392  a cookie is a small file that is downloaded an...    0        0
# 1393  cookies allow the website, amongst other thing...    0        0
# 1394  the user has the option to prevent the generat...    0        0
# 1395  you can obtain more information by reading our...    0        0
# 1396                           last updated: 2021/02/18    0        0
#
#       Acquired data  Data sharing  Rights
# 0                 0             0       0
# 1                 0             0       0
# 2                 0             0       0
# 3                 0             0       0
# 4                 0             0       0
# ...             ...           ...     ...
# 1392              0             0       0
# 1393              0             0       0
# 1394              0             0       0
# 1395              0             0       0
# 1396              0             0       0
#
# [1397 rows x 6 columns]

# %%
df_sme.head(50)
# Out:
#                                                  Text  DPO  Purpose  \
# 0                         privacy policy for go2learn    0        0
# 1                 , llc  updated: february 19, 2021      0        0
# 2                                         , llc  4198    0        0
# 3                                  meadow hill road      0        0
# 4                               cazenovia, ny 13035      0        0
# 5   go2learn, llc and our subsidiaries and affilia...    0        0
# 6               your privacy is very important to us.    0        0
# 7   our goal is to deliver content targeted to the...    0        0
# 8   in order to provide you with relevant informat...    0        0
# 9   this privacy policy applies to all products an...    0        0
# 10  please read this privacy policy carefully and ...    0        0
# 11  please be advised that no computer system shou...    0        0
# 12  however, we use the latest encryption methods ...    0        0
# 13  also, be advised that we have never and will n...    0        0
# 14  types of data collection  go2learn collects da...    0        0
# 15  automated means such as communications, protoc...    0        0
# 16  offline communications and interactions  third...    0        0
# 17  depending upon the method of collection and us...    0        0
# 18  a) electronic communications protocols and coo...    0        0
# 19  this information often consists of network rou...    0        0
# 20  at this time our server will also query your c...    0        0
# 21  a “cookie” is a small piece of information sen...    0        0
# 22  some parts of the go2learn web sites use cooki...    0        0
# 23  the information collected from cookies is trac...    0        0
# 24  cookies on the site may collect the following ...    0        0
# 25                     go2learn’s online communities.    0        0
# 26  cookies on the site, and the associated data, ...    0        0
# 27  some cookies used by go2learn’s web sites may ...    0        0
# 28  (as discussed in more detail below, you can se...    0        0
# 29  there may be some cookies on certain tools tha...    0        0
# 30  cookies may also be of benefit to you by creat...    0        0
# 31  in the future, as we enable further customizat...    0        0
# 32  while we do not offer an opt-out on the site f...    0        0
# 33  you can set your web browser to alert you when...    0        0
# 34  you can also get information on the duration o...    0        0
# 35  you then have the opportunity to accept or rej...    0        0
# 36  additionally, you can set your browser to refu...    0        0
# 37  you can generally disable the cookie feature o...    0        0
# 38            the data we collect and how we use it      0        0
# 39  go2learn collects data from you for the follow...    0        0
# 40       to engage in transactions or communications.    0        0
# 41  name, address, email, purchase details, and cr...    0        0
# 42  the majority of the data collected under this ...    0        0
# 43  go2learn may need to share some of this data (...    0        0
# 44  name, address, email, purchase details, and cr...    0        0
# 45  the majority of the data collected under this ...    0        0
# 46  go2learn may need to share some of this data (...    0        0
# 47             to provide future service and support.    0        0
# 48  information collected for this purpose is both...    0        0
# 49  this information is also used to provide servi...    0        0
#
#     Acquired data  Data sharing  Rights
# 0               0             0       0
# 1               0             0       0
# 2               0             0       0
# 3               0             0       0
# 4               0             0       0
# 5               0             0       0
# 6               0             0       0
# 7               0             0       0
# 8               0             0       0
# 9               0             0       0
# 10              0             0       0
# 11              0             0       0
# 12              0             0       0
# 13              0             0       0
# 14              0             0       0
# 15              0             0       0
# 16              0             0       0
# 17              0             0       0
# 18              0             0       0
# 19              0             0       0
# 20              0             0       0
# 21              0             0       0
# 22              0             0       0
# 23              0             0       0
# 24              0             0       0
# 25              0             0       0
# 26              0             0       0
# 27              0             0       0
# 28              0             0       0
# 29              0             0       0
# 30              0             0       0
# 31              0             0       0
# 32              0             0       0
# 33              0             0       0
# 34              0             0       0
# 35              0             0       0
# 36              0             0       0
# 37              0             0       0
# 38              0             0       0
# 39              0             0       0
# 40              0             0       0
# 41              0             0       0
# 42              0             0       0
# 43              0             0       0
# 44              0             0       0
# 45              0             0       0
# 46              0             0       0
# 47              0             0       0
# 48              0             0       0
# 49              0             0       0

# %%
df_sme.to_csv(r'data/SME-GDPR-test.csv', sep='\t', encoding='utf-8', index=False)
df_le.to_csv(r'data/LE-GDPR-test.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# #### Selected inverse indices from the list of indices that was selected to create the test set
# - this is the final set that will be used for comparing the GDPR-compliance or GDPR-awareness between SMEs and LEs

# %%
final_sme = [sme for ind, sme in enumerate(SME_list) if ind not in idx_list]
final_le = [le for ind, le in enumerate(LE_list) if ind not in idx_list]
#2177

# %%
len(f_pps_sme_final)
# final_sme.index('JAMONES EL CHARRO SA')
# Out:
# 277

# %% [markdown]
# ## SMEs: scrape 1000 policies

# %%
# pps_sme_final = []
# f_pps_sme_final = []

for company in final_sme:
    query = company + " privacy policy"
    print(" - - - " + company + " - - - ")
    out = scrape_policies_google(query)
    
    if(len(out) != 0):
        pps_sme_final.extend(out)
        f_pps_sme_final.append(out)
        print("Number of scraped policies: ", len(f_pps_sme_final))
        print("")
    if(len(f_pps_sme_final) == 1000):
        break
# Out:
#  - - - J - - -
# https://www.junaidjamshed.com/privacy-policy-j
# Number of scraped policies:  258
#
#  - - - A - - -
# https://en.wikipedia.org/wiki/Privacy_policy
# Number of scraped policies:  259
#
#  - - - M - - -
# https://www.groupm.com/mplatform-privacy-notice/
# Number of scraped policies:  260
#
#  - - - O - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/?sa=X&ved=2ahUKEwiPi6jXuP3wAhXCO-wKHTAjDKEQ9QF6BAgGEAI
# Number of scraped policies:  261
#
#  - - - N - - -
# https://www.modeln.com/privacy-policy/
# Number of scraped policies:  262
#
#  - - - E - - -
# https://ec.europa.eu/info/privacy-policy_en
# Number of scraped policies:  263
#
#  - - - S - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/
# Number of scraped policies:  264
#
#  - - -   - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/?sa=X&ved=2ahUKEwif_9DfuP3wAhUpgP0HHS3TDZEQ9QF6BAgKEAI
# Number of scraped policies:  265
#
#  - - - E - - -
# https://ec.europa.eu/info/privacy-policy_en
# Number of scraped policies:  266
#
#  - - - L - - -
# https://en.wikipedia.org/wiki/Privacy_policy
# Number of scraped policies:  267
#
#  - - -   - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/?sa=X&ved=2ahUKEwim5sbluP3wAhUkMewKHdULCp4Q9QF6BAgGEAI
# Number of scraped policies:  268
#
#  - - - C - - -
# https://en.wikipedia.org/wiki/Privacy_policy
# Number of scraped policies:  269
#
#  - - - H - - -
# https://ec.europa.eu/info/privacy-policy_en
# Number of scraped policies:  270
#
#  - - - A - - -
# https://en.wikipedia.org/wiki/Privacy_policy
# Number of scraped policies:  271
#
#  - - - R - - -
# https://www.reddit.com/r/privacy/
# Number of scraped policies:  272
#
#  - - - R - - -
# https://www.reddit.com/r/privacy/
# Number of scraped policies:  273
#
#  - - - O - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/?sa=X&ved=2ahUKEwjr9JLyuP3wAhWLraQKHe_2Dp4Q9QF6BAgGEAI
# Number of scraped policies:  274
#
#  - - -   - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/?sa=X&ved=2ahUKEwjc8Yb0uP3wAhWQGuwKHRXnCKEQ9QF6BAgGEAI
# Number of scraped policies:  275
#
#  - - - S - - -
# https://www.privacypolicies.com/blog/privacy-policy-template/
# Number of scraped policies:  276
#
#  - - - A - - -
# https://en.wikipedia.org/wiki/Privacy_policy
# Number of scraped policies:  277

# %%
#clean list of sentences
pps_sme_final = [(str(sen).lower()) for sen in pps_sme_final if len(sen) > 3]

#clean list of list of sentences - this will be the output file
f_pps_sme_final = [[(str(sen).lower()).replace(";","") for sen in pol if len(sen) > 3] for pol in f_pps_sme_final]

# %% [markdown]
# #### Write policies to separate files

# %%
calc_len = 0
for i, policy in enumerate(f_pps_sme_final):
    zer_list = [0] * len(policy)
    
    calc_len = calc_len + len(zer_list)
    # d = {'Text': pps, 'DPO': zer_list, 'Purpose': zer_list, 'Acquired data': zer_list, 'Data sharing': zer_list, 'Rights': zer_list}

    df_sme_f = pd.DataFrame(list(zip(policy, zer_list,zer_list,zer_list,zer_list,zer_list)),
                                     columns =['Text', 'DPO', 'Purpose', 'Acquired data', 'Data sharing', 'Rights'])

    # extra cleaning
    df_sme_f = df_sme_f.replace('\n',' ', regex=True)
    df_sme_f.to_csv(r'data/SME/' + str(i) + '.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# #### Average policy length of the policies (SME): 92 sentences

# %%
print(calc_len/len(f_pps_sme_final))
# Out:
# 91.995

# %% [markdown]
# ## LEs: scrape 1000 policies

# %%
# pps_le_final = []
# f_pps_le_final = []

for company in final_le_ctd:
    query = company + " privacy policy"
    print(" - - - " + company + " - - - ")
    out = scrape_policies_google(query)
    
    if(len(out) != 0):
        pps_le_final.extend(out)
        f_pps_le_final.append(out)
        print("Number of scraped policies: ", len(f_pps_le_final))
        print("")
    if(len(f_pps_le_final) == 1000):
        break
# Out:
#  - - - ARCE CERAMICAS SL - - -
#  - - - CINTRA - URBANIZACOES, TURISMO E CONSTRUCOES, S.A. - - -
#  - - - VTA AUSTRIA GMBH - - -
# https://vta.cc/en/privacy-policy
# Number of scraped policies:  981
#
#  - - - POWSZECHNA SPOLDZIELNIA MIESZKANIOWA RENAWA - - -
#  - - - "HENCKE SYSTEMBERATUNG" GMBH - - -
#  - - - CHASTAGNER LOCATION - - -
#  - - - BREDA TECNOLOGIE COMMERCIALI S.R.L. - - -
# http://www.breda.tech/en/cookie-policy/
# Number of scraped policies:  982
#
#  - - - TAZAKI FOODS LIMITED - - -
#  - - - DUVAL ELECTRICITE - - -
# https://www.tranzcom.com/en/privacy-policy/
# Number of scraped policies:  983
#
#  - - - CASTILLO DE SAN LUIS SL - - -
#  - - - TAYS SYDANKESKUS OY - - -
#  - - - RW EINDHOVEN BLOK 59 B.V. - - -
#  - - - GEDO GRUNDSTUECKSENTWICKLUNGS UND  VERWALTUNGSGESELLSCHAFT MBH & CO. KG - - -
#  - - - DEMAG ERGOTECH GMBH - - -
# https://www.sumitomo-shi-demag.eu/privacy-policy
# Number of scraped policies:  984
#
#  - - - PERRIN ET FILS - - -
#  - - - THERMO ELECTRON SWEDEN AB - - -
#  - - - BAVARIAN NORDIC A/S - - -
# https://www.bavarian-nordic.com/privacy.aspx
# Number of scraped policies:  985
#
#  - - - KERRY GROUP PLC - - -
# https://www.kerryfoodservice.com/pages/privacy-policy-kerry-brands
# Number of scraped policies:  986
#
#  - - - EASYFAIRS INTERNATIONAL - - -
#  - - - ORDIA HANDELS GES.M.B.H. - - -
#  - - - SAREVI - - -
#  - - - MALCOP SL - - -
#  - - - BLUMBERG BETEILIGUNGS GMBH - - -
# https://www.wd-beteiligung.at/privacypolicy/
# Number of scraped policies:  987
#
#  - - - V.N.W. TRANSPORT - - -
# https://www.transportenvironment.org/privacy-policy
# Number of scraped policies:  988
#
#  - - - ALIAGAS S.A. - - -
# https://aliaxis.com/privacy-statement/
# Number of scraped policies:  989
#
#  - - - OTB HOLDING BORAAS AB - - -
#  - - - PAUL RAUSCHERT STEINBACH GMBH - - -
#  - - - GMINA KLECKO - - -
#  - - - S.U.C.T. SA - - -
#  - - - JAGUAR LAND ROVER SLOVAKIA, S.R.O. - - -
# https://www.jaguar.com/privacy-policy/index.html
# Number of scraped policies:  990
#
#  - - - DAVID ROSAS, LDA - - -
# https://davidrosas.com/pages/privacy-policy
# Number of scraped policies:  991
#
#  - - - PALOMAR - S.R.L. - - -
# https://www.palomarweb.com/privacy-policy/
# Number of scraped policies:  992
#
#  - - - ECOPHYSE - - -
#  - - - AVIVA INVESTORS E-RELI DANONE SARL - - -
# https://www.avivainvestors.com/en-us/site-information/privacy-notice/
# Number of scraped policies:  993
#
#  - - - TURIEN & CO. ASSURADEUREN B.V. - - -
#  - - - TORNATOR OYJ - - -
#  - - - EDEN SPRINGS SP. Z O.O. - - -
#  - - - GERMA'S SHOES SL - - -
#  - - - FENEKO - - -
# https://www.emakina.com/en-be/privacy-policy
# Number of scraped policies:  994
#
#  - - - TECNOSCAVI DI AZZINI STEFANO & C. S.A.S. - - -
#  - - - GADINVEST A/S - - -
#  - - - RAIFFEISENBANK SCHWANBERG EGEN - - -
#  - - - CENTRUM KROKUS SP. Z O.O. - - -
#  - - - KRONOBEL B.V. - - -
# https://www.base.be/en/legal-information/privacy-policy.html
# Number of scraped policies:  995
#
#  - - - SANDVIKENS STADSHUS AB - - -
#  - - - KURETA GMBH - - -
#  - - - ROTH INDUSTRIES GMBH & CO. KG - - -
# https://www.roth-werke.de/en/roth-legal-notice.htm
# Number of scraped policies:  996
#
#  - - - DAB GROUP AB - - -
# https://dabgroup.se/privacy-policy/?lang=en
# Number of scraped policies:  997
#
#  - - - J VILASECA SA - - -
#  - - - ODIN FORVALTNINGSAKTIEBOLAG - - -
# https://odinfundmanagement.com/privacy-policy/
# Number of scraped policies:  998
#
#  - - - NS REIZIGERS B.V. - - -
#  - - - GEVEKO MARKINGS SWEDEN AB - - -
#  - - - SAIC LEASING 1 LIMITED - - -
# https://www.saic.com/privacy-statement
# Number of scraped policies:  999
#
#  - - - HAVAS MANAGEMENT ESPANA SL - - -
#  - - - WALTNER GRUNDSTUECKS- UND BETEILIGUNGS-GMBH - - -
# https://www.wd-beteiligung.at/privacypolicy/
# Number of scraped policies:  1000

# %%
len(final_le)
final_le[2819]
final_le_ctd = final_le[2819:]
print(len(final_le))
print(len(final_le_ctd))
# Out:
# 49950
# 47131

# %%
#clean list of sentences
pps_le_final = [(str(sen).lower()) for sen in pps_le_final if len(sen) > 3]

#clean list of list of sentences - this will be the output file
f_pps_le_final = [[(str(sen).lower()).replace(";","") for sen in pol if len(sen) > 3] for pol in f_pps_le_final]

# %% [markdown]
# #### Write policies to separate files

# %%
calc_len = 0
for i, policy in enumerate(f_pps_le_final):
    zer_list = [0] * len(policy)
    
    calc_len = calc_len + len(zer_list)
    # d = {'Text': pps, 'DPO': zer_list, 'Purpose': zer_list, 'Acquired data': zer_list, 'Data sharing': zer_list, 'Rights': zer_list}

    df_le_f = pd.DataFrame(list(zip(policy, zer_list,zer_list,zer_list,zer_list,zer_list)),
                                     columns =['Text', 'DPO', 'Purpose', 'Acquired data', 'Data sharing', 'Rights'])

    # extra cleaning
    df_le_f = df_le_f.replace('\n',' ', regex=True)
    df_le_f.to_csv(r'data/LE/' + str(i) + '.csv', sep='\t', encoding='utf-8', index=False)

# %% [markdown]
# #### Average length of the policies (LEs): 2.74 sentences

# %%
print(calc_len/len(f_pps_sme_final))
# Out:
# 90.25
